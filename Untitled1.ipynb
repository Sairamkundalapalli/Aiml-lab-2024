# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairamkundalapalli/Aiml-lab-2024/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets
import seaborn as sns
# %matplotlib inLine
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
df.head()
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
df.columns
plt.figure((figsize=(10,7))
sns.heatmap(df.corr(),annot=True ,linewidth=2
print("Feature set size:",x.shape)
print("Variable set size:",y.shape)

l_colun=list(df.columns)
len_feature=len(l.column)
l.column
# Out:
#   File "<ipython-input-6-2ec61a1bc95b>", line 11
#     plt.figure((figsize=(10,7))
#                 ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets
import seaborn as sns
# %matplotlib inLine
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
df.head()
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
df.columns
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True ,linewidth=2)
x=df[l_column[0:len_feature-2]]
y=df[l_column[len_feature-2]]
print("Feature set size:",x.shape)
print("Variable set size:",y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-839b8ba12044> in <cell line: 13>()
#      11 plt.figure(figsize=(10,7))
#      12 sns.heatmap(df.corr(),annot=True ,linewidth=2)
# ---> 13 x=df[l_column[0:len_feature-2]]
#      14 y=df[l_column[len_feature-2]]
#      15 print("Feature set size:",x.shape)
#
# NameError: name 'l_column' is not defined

# %%
x=df[l_column[0:len_feature-2]]
y=df[l_column[len_feature-2]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bc5285ae4068> in <cell line: 1>()
# ----> 1 x=df[l_column[0:len_feature-2]]
#       2 y=df[l_column[len_feature-2]]
#
# NameError: name 'l_column' is not defined
